# %%
#Vikas-Jupyter Notebook
#https://insights.stackoverflow.com/survey

# %%
#1)Basic Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv")
schema_df=pd.read_csv("data/survey_results_schema.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df.shape
# Out:
# (88883, 85)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88883 entries, 0 to 88882
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              88883 non-null  int64
#  1   MainBranch              88331 non-null  object
#  2   Hobbyist                88883 non-null  object
#  3   OpenSourcer             88883 non-null  object
#  4   OpenSource              86842 non-null  object
#  5   Employment              87181 non-null  object
#  6   Country                 88751 non-null  object
#  7   Student                 87014 non-null  object
#  8   EdLevel                 86390 non-null  object
#  9   UndergradMajor          75614 non-null  object
#  10  EduOther                84260 non-null  object
#  11  OrgSize                 71791 non-null  object
#  12  DevType                 81335 non-null  object
#  13  YearsCode               87938 non-null  object
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(7)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
# 5                       Never
# 6                       Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(8)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.head(10)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
# 5           6  I am not primarily a developer, but I write co...      Yes
# 6           7                     I am a developer by profession       No
# 7           8                        I code primarily as a hobby      Yes
# 8           9                     I am a developer by profession      Yes
# 9          10                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# ...

# %%
df.tail()
# Out:
#        Respondent MainBranch Hobbyist  \
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
#                                               OpenSource  \
# 88878  The quality of OSS and closed source software ...
# 88879  The quality of OSS and closed source software ...
# 88880                                                NaN
# 88881  OSS is, on average, of HIGHER quality than pro...
# 88882  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.tail(9)
# Out:
#        Respondent MainBranch Hobbyist  \
# 88874       88076        NaN       No
# 88875       88182        NaN      Yes
# 88876       88212        NaN       No
# 88877       88282        NaN      Yes
# 88878       88377        NaN      Yes
# 88879       88601        NaN       No
# 88880       88802        NaN       No
# 88881       88816        NaN       No
# 88882       88863        NaN      Yes
#
#                                              OpenSourcer  \
# 88874                                              Never
# 88875                         Once a month or more often
# 88876                            Less than once per year
# 88877                         Once a month or more often
# 88878  Less than once a month but more than once per ...
# 88879                                              Never
# 88880                                              Never
# 88881                                              Never
# 88882                            Less than once per year
#
# ...

# %%
#2)Series Datatypes

# %%
#Check Pandas-Demo-2 for information about loc and iloc and come back to Pandas-Demo-1 to continue

# %%
df["Hobbyist"]
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts()
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df.loc[0,"Hobbyist"]
# Out:
# 'Yes'

# %%
df.loc[[0,1,2],"Hobbyist":"Employment"]
# Out:
#   Hobbyist              OpenSourcer  \
# 0      Yes                    Never
# 1       No  Less than once per year
# 2      Yes                    Never
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
#
#                                Employment
# 0  Not employed, and not looking for work
# 1      Not employed, but looking for work
# 2                      Employed full-time

# %%
#3) indexing

# %%
dfi=pd.read_csv("data/survey_results_public.csv",index_col="Respondent")

# %%
dfi
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
schema_df1=schema_df=pd.read_csv("data/survey_results_schema.csv",index_col="Column")

# %%
schema_df1
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df1.loc["MgrIdiot"]
# Out:
# QuestionText    How confident are you that your manager knows ...
# Name: MgrIdiot, dtype: object

# %%
schema_df1.loc["MgrIdiot","QuestionText"]
#This is how indexing helps use because we can use the string to access the data where ever we want to
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df1.sort_index() #Indexes are sorted alphabetically in ascending order
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]

# %%
schema_df1.sort_index(ascending=False) #Indexes are sorted alphabetically in descending order
#Both the times dataframe is not changed because we did not use inplace=True
# Out:
#                                                     QuestionText
# Column
# YearsCodePro   How many years have you coded professionally (...
# YearsCode      Including any education, how many years have y...
# WorkWeekHrs     On average, how many hours per week do you work?
# WorkRemote                       How often do you work remotely?
# WorkPlan                 How structured or planned is your work?
# ...                                                          ...
# BlockchainOrg  How is your organization thinking about or imp...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BetterLife     Do you think people born today will have a bet...
# Age1stCode     At what age did you write your first line of c...
# Age            What is your age (in years)? If you prefer not...
#
# [85 rows x 1 columns]

# %%
#4)filtering the data.

# %%
high_sal_filter = (df["ConvertedComp"]>70000)

# %%
df.loc[high_sal_filter,["Country","LanguageWorkedWith","ConvertedComp"]]
# Out:
#               Country                                 LanguageWorkedWith  \
# 5              Canada                                         Java;R;SQL
# 8         New Zealand  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;P...
# 12      United States  Bash/Shell/PowerShell;HTML/CSS;JavaScript;PHP;...
# 15     United Kingdom  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;T...
# 21      United States  Bash/Shell/PowerShell;C++;HTML/CSS;JavaScript;...
# ...               ...                                                ...
# 88323   United States  Bash/Shell/PowerShell;C#;HTML/CSS;Java;Python;...
# 88324   United States  Bash/Shell/PowerShell;C;Clojure;HTML/CSS;Java;...
# 88325   United States               HTML/CSS;JavaScript;Scala;TypeScript
# 88326         Finland                   Bash/Shell/PowerShell;C++;Python
# 88329     Netherlands             C#;HTML/CSS;Java;JavaScript;PHP;Python
#
#        ConvertedComp
# 5           366420.0
# 8            95179.0
# 12           90000.0
# ...

# %%
countries=["United States","India","Canada","Germany","United Kingdom"]
filter_country=df["Country"].isin(countries)

# %%
df.loc[filter_country,"Country"]
# Out:
# 0        United Kingdom
# 3         United States
# 5                Canada
# 7                 India
# 9                 India
#               ...
# 88859     United States
# 88863    United Kingdom
# 88864             India
# 88877     United States
# 88878            Canada
# Name: Country, Length: 45008, dtype: object

# %%
filter_lang=df["LanguageWorkedWith"].str.contains("Python",na=False)
df.loc[filter_lang,"LanguageWorkedWith"]
# Out:
# 0                          HTML/CSS;Java;JavaScript;Python
# 1                                      C++;HTML/CSS;Python
# 3                                      C;C++;C#;Python;SQL
# 4              C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7        Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
#                                ...
# 88854    Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 88860      Bash/Shell/PowerShell;C++;Python;Ruby;Other(s):
# 88865      Bash/Shell/PowerShell;HTML/CSS;Python;Other(s):
# 88872             C;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# 88876                           HTML/CSS;JavaScript;Python
# Name: LanguageWorkedWith, Length: 36443, dtype: object

# %%
#Work with different filters in pandas Demo-2

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#Rename ConvertedComp with Salary

# %%
df.rename(columns={"ConvertedComp":"Salary"},inplace=True)
df["Salary"]
# Out:
# 0            NaN
# 1            NaN
# 2         8820.0
# 3        61000.0
# 4            NaN
#           ...
# 88878        NaN
# 88879        NaN
# 88880        NaN
# 88881        NaN
# 88882        NaN
# Name: Salary, Length: 88883, dtype: float64

# %%
df.set_index("Respondent",inplace=True)

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4         No
# 5        Yes
#         ...
# 88377    Yes
# 88601     No
# 88802     No
# 88816     No
# 88863    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
#Convert Hobbyist yes to True and no to False
df["Hobbyist"]=df["Hobbyist"].map({"Yes":True,"No":False})#map works for this example because there are no other values other than yes and no but it is best to use replace

# %%
df["Hobbyist"]
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4        False
# 5         True
#          ...
# 88377     True
# 88601    False
# 88802    False
# 88816    False
# 88863     True
# Name: Hobbyist, Length: 88883, dtype: bool

# %%
#7)Sorting df

# %%
df.sort_values(by=["Country"],inplace=True)

# %%
df.head(50)
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 39258                          I am a developer by profession      True
# 63129                          I am a developer by profession      True
# 85715                          I am a developer by profession     False
# 50767                          I am a developer by profession     False
# 2782                                                      NaN      True
# 63019                                                     NaN     False
# 6417                   I am a student who is learning to code      True
# 40000                  I am a student who is learning to code      True
# 88731                             I code primarily as a hobby      True
# 48436                          I am a developer by profession     False
# 10746                          I am a developer by profession      True
# 62525                  I am a student who is learning to code      True
# ...

# %%
df.sort_values(by=["Country","Salary"],inplace=True)

# %%
df.sort_values(by=["Country","Salary"],inplace=True,ascending=[True,False])

# %%
df[["Salary","Country"]]
# Out:
#                Salary      Country
# Respondent
# 63129       1000000.0  Afghanistan
# 50499        153216.0  Afghanistan
# 39258         19152.0  Afghanistan
# 58450         17556.0  Afghanistan
# 7085          14364.0  Afghanistan
# ...               ...          ...
# 88062             NaN          NaN
# 88076             NaN          NaN
# 88601             NaN          NaN
# 88802             NaN          NaN
# 88816             NaN          NaN
#
# [88883 rows x 2 columns]

# %%
#Largest salaries
df["Salary"].nlargest(10)
# Out:
# Respondent
# 25983    2000000.0
# 87896    2000000.0
# 22013    2000000.0
# 28243    2000000.0
# 72732    2000000.0
# 78151    2000000.0
# 80200    2000000.0
# 52132    2000000.0
# 75561    2000000.0
# 32250    2000000.0
# Name: Salary, dtype: float64

# %%
df.nlargest(10,"Salary")
# Out:
#                                                    MainBranch  Hobbyist  \
# Respondent
# 25983                          I am a developer by profession      True
# 87896                          I am a developer by profession      True
# 22013                          I am a developer by profession      True
# 28243                          I am a developer by profession      True
# 72732       I am not primarily a developer, but I write co...     False
# 78151                          I am a developer by profession      True
# 80200                          I am a developer by profession      True
# 52132                          I am a developer by profession      True
# 75561                          I am a developer by profession      True
# 32250                          I am a developer by profession      True
#
#                                                   OpenSourcer  \
# Respondent
# 25983                                 Less than once per year
# ...

# %%
df.nsmallest(10,"Salary")["Salary"]
# Out:
# Respondent
# 28638    0.0
# 722      0.0
# 13825    0.0
# 40913    0.0
# 30630    0.0
# 69049    0.0
# 19340    0.0
# 16214    0.0
# 29355    0.0
# 1685     0.0
# Name: Salary, dtype: float64

# %%
#Grouping and Aggregating Data(Most important part of analytics)

# %%
df = pd.read_csv("data/survey_results_public.csv")
schema_df=pd.read_csv("data/survey_results_schema.csv",index_col="Column")

# %%
#Aggregate functions give us mean median and mode of the data

# %%
#Salary Column is the ConvertedComp

# %%
df["ConvertedComp"].head(15)
# Out:
# 0          NaN
# 1          NaN
# 2       8820.0
# 3      61000.0
# 4          NaN
# 5     366420.0
# 6          NaN
# 7          NaN
# 8      95179.0
# 9      13293.0
# 10         NaN
# 11         NaN
# 12     90000.0
# 13     57060.0
# 14         NaN
# Name: ConvertedComp, dtype: float64

# %%
df["ConvertedComp"].median()
# Out:
# 57287.0

# %%
#Median salary by country can be done using grouping. We can look at it later

# %%
df.median()#It will find columns with numerical values and find the median
# Out:
# Respondent       44442.0
# CompTotal        62000.0
# ConvertedComp    57287.0
# WorkWeekHrs         40.0
# CodeRevHrs           4.0
# Age                 29.0
# dtype: float64

# %%
df.describe()#Broad overview of the stats. 50% value is the median
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
#We dont check mean usually because it is effected generally due to outliers. It is always best to consider median

# %%
df["ConvertedComp"].describe()#count is the number of non NaN rows
# Out:
# count    5.582300e+04
# mean     1.271107e+05
# std      2.841523e+05
# min      0.000000e+00
# 25%      2.577750e+04
# 50%      5.728700e+04
# 75%      1.000000e+05
# max      2.000000e+06
# Name: ConvertedComp, dtype: float64

# %%
df["Hobbyist"]#If coding was a Hobby
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 88878    Yes
# 88879     No
# 88880     No
# 88881     No
# 88882    Yes
# Name: Hobbyist, Length: 88883, dtype: object

# %%
df["Hobbyist"].value_counts()#Mostly used to analyze data
# Out:
# Yes    71257
# No     17626
# Name: Hobbyist, dtype: int64

# %%
df["SocialMedia"]#What social media is used most by the users
# Out:
# 0          Twitter
# 1        Instagram
# 2           Reddit
# 3           Reddit
# 4         Facebook
#            ...
# 88878      YouTube
# 88879          NaN
# 88880          NaN
# 88881          NaN
# 88882     WhatsApp
# Name: SocialMedia, Length: 88883, dtype: object

# %%
schema_df.loc["SocialMedia"]
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
df["SocialMedia"].value_counts()
# Out:
# Reddit                      14374
# YouTube                     13830
# WhatsApp                    13347
# Facebook                    13178
# Twitter                     11398
# Instagram                    6261
# I don't use social media     5554
# LinkedIn                     4501
# WeChat 微信                     667
# Snapchat                      628
# VK ВКонта́кте                 603
# Weibo 新浪微博                     56
# Youku Tudou 优酷                 21
# Hello                          19
# Name: SocialMedia, dtype: int64

# %%
df["SocialMedia"].value_counts(normalize=True)*100#Broken down by percentage
# Out:
# Reddit                      17.023343
# YouTube                     16.379076
# WhatsApp                    15.807051
# Facebook                    15.606902
# Twitter                     13.498822
# Instagram                    7.414996
# I don't use social media     6.577685
# LinkedIn                     5.330602
# WeChat 微信                    0.789938
# Snapchat                     0.743750
# VK ВКонта́кте                0.714142
# Weibo 新浪微博                   0.066322
# Youku Tudou 优酷               0.024871
# Hello                        0.022502
# Name: SocialMedia, dtype: float64

# %%
#Grouping the data by country and see social media % by country

# %%
df["Country"].value_counts()#Most of the data was answered by users from US and then comes India and Germany
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Chad                                    1
# Saint Vincent and the Grenadines        1
# Niger                                   1
# Dominica                                1
# Name: Country, Length: 179, dtype: int64

# %%
g1=df.groupby("Country")

# %%
g1.get_group("India")
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt = df["Country"] == "India"

# %%
df.loc[filt]#It is the same as we got in groupby. but we have all the groups in the groupby function
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
g1.get_group("India")["SocialMedia"].value_counts()
# Out:
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# WeChat 微信                      5
# Hello                          5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
g1["SocialMedia"].value_counts().head(50)
# Out:
# Country              SocialMedia
# Afghanistan          Facebook                     15
#                      YouTube                       9
#                      I don't use social media      6
#                      WhatsApp                      4
#                      Instagram                     1
#                      LinkedIn                      1
#                      Twitter                       1
# Albania              WhatsApp                     18
#                      Facebook                     16
#                      Instagram                    13
#                      YouTube                      10
#                      Twitter                       8
#                      LinkedIn                      7
#                      Reddit                        6
#                      I don't use social media      4
#                      Snapchat                      1
#                      WeChat 微信                     1
# ...

# %%
g1["SocialMedia"].value_counts().loc["India"]
# Out:
# SocialMedia
# WhatsApp                    2990
# YouTube                     1820
# LinkedIn                     955
# Facebook                     841
# Instagram                    822
# Twitter                      542
# Reddit                       473
# I don't use social media     250
# Snapchat                      23
# Hello                          5
# WeChat 微信                      5
# VK ВКонта́кте                  4
# Youku Tudou 优酷                 2
# Weibo 新浪微博                     1
# Name: SocialMedia, dtype: int64

# %%
g1["SocialMedia"].value_counts().loc["China"]
# Out:
# SocialMedia
# WeChat 微信                   403
# YouTube                      53
# Weibo 新浪微博                   42
# I don't use social media     27
# Twitter                      27
# Reddit                       12
# LinkedIn                     11
# Facebook                      8
# Instagram                     7
# Youku Tudou 优酷                7
# WhatsApp                      3
# VK ВКонта́кте                 1
# Name: SocialMedia, dtype: int64

# %%
g1["SocialMedia"].value_counts().loc["Russian Federation"]
# Out:
# SocialMedia
# VK ВКонта́кте               442
# YouTube                     302
# I don't use social media    155
# Reddit                      140
# Twitter                     130
# Instagram                    94
# WhatsApp                     90
# Facebook                     67
# LinkedIn                     35
# Snapchat                      1
# Name: SocialMedia, dtype: int64

# %%
g1["ConvertedComp"].median()#Using aggregate functions with grouping
# Out:
# Country
# Afghanistan                               6222.0
# Albania                                  10818.0
# Algeria                                   7878.0
# Andorra                                 160931.0
# Angola                                    7764.0
#                                           ...
# Venezuela, Bolivarian Republic of...      6384.0
# Viet Nam                                 11892.0
# Yemen                                    11940.0
# Zambia                                    5040.0
# Zimbabwe                                 19200.0
# Name: ConvertedComp, Length: 179, dtype: float64

# %%
g1["ConvertedComp"].median().loc["Germany"]#Using aggregate functions with grouping to check median of a single country
# Out:
# 63016.0

# %%
#agg
g1["ConvertedComp"].agg(["median","mean"])
# Out:
#                                         median           mean
# Country
# Afghanistan                             6222.0  101953.333333
# Albania                                10818.0   21833.700000
# Algeria                                 7878.0   34924.047619
# Andorra                               160931.0  160931.000000
# Angola                                  7764.0    7764.000000
# ...                                        ...            ...
# Venezuela, Bolivarian Republic of...    6384.0   14581.627907
# Viet Nam                               11892.0   17233.436782
# Yemen                                  11940.0   16909.166667
# Zambia                                  5040.0   10075.375000
# Zimbabwe                               19200.0   34046.666667
#
# [179 rows x 2 columns]

# %%
g1["ConvertedComp"].agg(["median","mean"]).loc["Canada"]
# Out:
# median     68705.000000
# mean      134018.564909
# Name: Canada, dtype: float64

# %%
#Using aggregate functions as filters

# %%
filt=df["Country"] == "India"
df.loc[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt=df["Country"] == "India"
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# 7         True
# 9         True
# 14       False
# 49        True
# 64       False
#          ...
# 88808    False
# 88825     True
# 88852    False
# 88853     True
# 88864    False
# Name: LanguageWorkedWith, Length: 9061, dtype: object

# %%
filt=df["Country"] == "India"
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').value_counts()
# Out:
# False    5739
# True     3105
# Name: LanguageWorkedWith, dtype: int64

# %%
filt=df["Country"] == "India"
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# 3105

# %%
g1['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
cr=df["Country"].value_counts()
cr
# Out:
# United States                       20949
# India                                9061
# Germany                              5866
# United Kingdom                       5737
# Canada                               3395
#                                     ...
# Papua New Guinea                        1
# Chad                                    1
# Saint Vincent and the Grenadines        1
# Niger                                   1
# Dominica                                1
# Name: Country, Length: 179, dtype: int64

# %%
Country_uses_python=g1['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
Country_uses_python
# Out:
# Country
# Afghanistan                              8
# Albania                                 23
# Algeria                                 40
# Andorra                                  0
# Angola                                   2
#                                         ..
# Venezuela, Bolivarian Republic of...    28
# Viet Nam                                78
# Yemen                                    3
# Zambia                                   4
# Zimbabwe                                14
# Name: LanguageWorkedWith, Length: 179, dtype: int64

# %%
pydf=pd.concat([cr,Country_uses_python],axis=1)
pydf
# Out:
#                                   Country  LanguageWorkedWith
# United States                       20949               10083
# India                                9061                3105
# Germany                              5866                2451
# United Kingdom                       5737                2384
# Canada                               3395                1558
# ...                                   ...                 ...
# Papua New Guinea                        1                   0
# Chad                                    1                   0
# Saint Vincent and the Grenadines        1                   0
# Niger                                   1                   1
# Dominica                                1                   1
#
# [179 rows x 2 columns]

# %%
pydf.columns=["Total Respondants","Respondants who knows Python"]

# %%
pydf
# Out:
#                                   Total Respondants  \
# United States                                 20949
# India                                          9061
# Germany                                        5866
# United Kingdom                                 5737
# Canada                                         3395
# ...                                             ...
# Papua New Guinea                                  1
# Chad                                              1
# Saint Vincent and the Grenadines                  1
# Niger                                             1
# Dominica                                          1
#
#                                   Respondants who knows Python
# United States                                            10083
# India                                                     3105
# Germany                                                   2451
# United Kingdom                                            2384
# ...

# %%
pydf["percent_knows_python"]=(pydf["Respondants who knows Python"]/pydf["Total Respondants"])*100

# %%
pydf
# Out:
#                                   Total Respondants  \
# United States                                 20949
# India                                          9061
# Germany                                        5866
# United Kingdom                                 5737
# Canada                                         3395
# ...                                             ...
# Papua New Guinea                                  1
# Chad                                              1
# Saint Vincent and the Grenadines                  1
# Niger                                             1
# Dominica                                          1
#
#                                   Respondants who knows Python  \
# United States                                            10083
# India                                                     3105
# Germany                                                   2451
# United Kingdom                                            2384
# ...

# %%
pydf.sort_values("percent_knows_python",ascending=False).head(50)
# Out:
#                                   Total Respondants  \
# Dominica                                          1
# Niger                                             1
# Sao Tome and Principe                             1
# Timor-Leste                                       1
# Turkmenistan                                      7
# Mauritania                                        7
# Guinea                                            3
# Guyana                                            3
# Bahamas                                           3
# Uganda                                           72
# Iceland                                          49
# Benin                                             5
# Namibia                                           5
# Haiti                                             5
# Congo, Republic of the...                         7
# Oman                                             11
# Cuba                                             30
# ...
